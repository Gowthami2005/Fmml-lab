# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowthami2005/Fmml-lab/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 12:30:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   218MB/s    in 0.3s
#
# 2024-03-31 12:30:45 (218 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22264  1510.08633v1  In this paper we study nonconvex penalization ...  stat
# 33477   1302.5474v2  The ability to track the optimum of dynamic en...    cs
# 445    1605.08283v1  First steps towards a mathematical theory of d...    cs
# 18163  cs/0501072v1  In this paper, we present a rich semantic netw...    cs
# 14569  cs/0304006v1  We address the text-to-text generation problem...    cs
# ...             ...                                                ...   ...
# 21660   1306.0407v2  We introduce a general constructive setting of...  stat
# 12197  1710.04735v1  Ever growing volume and velocity of data coupl...  stat
# 18697   1110.2205v1  In this paper, we present two alternative appr...    cs
# 39118   1311.7401v1  Shape from texture refers to the extraction of...  stat
# 11308  1508.04904v1  In this paper we tackle the issue of clusterin...  stat
#
#                                                    title  year  \
# 22264  Nonconvex Penalization in Sparse Estimation: A...  2015
# 33477  On the performance of a hybrid genetic algorit...  2013
# 445    Discrete Deep Feature Extraction: A Theory and...  2016
# 18163  Inferring knowledge from a large semantic network  2005
# 14569  Learning to Paraphrase: An Unsupervised Approa...  2003
# ...                                                  ...   ...
# 21660  Constructive Setting of the Density Ratio Esti...  2013
# 12197  On the Runtime-Efficacy Trade-off of Anomaly D...  2017
# 18697  Answer Sets for Logic Programs with Arbitrary ...  2011
# 39118  Shape from Texture using Locally Scaled Point ...  2013
# 11308  Review and Perspective for Distance Based Traj...  2015
#
#                                                 keywords
# 22264  [nonconvex, penalization, bernstein, functions...
# 33477  [environments, important, practical, applicati...
# 445    [mathematical, convolutional, extraction, cont...
# 18163  [differential, implemented, differential, indu...
# 14569  [generation, paraphrasing, phenomenon, difficu...
# ...                                                  ...
# 21660  [introduce, constructive, estimation, approxim...
# 12197  [decreasing, attention, underscore, analytics,...
# 18697  [alternative, approaches, arbitrary, constrain...
# 39118  [extraction, information, irregular, introduce...
# 11308  [clustering, trajectories, geolocalized, obser...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22264    [nonconvex, penalization, bernstein, functions...
# 33477    [environments, important, practical, applicati...
# 445      [mathematical, convolutional, extraction, cont...
# 18163    [differential, implemented, differential, indu...
# 14569    [generation, paraphrasing, phenomenon, difficu...
#                                ...
# 20683    [hierarchical, reinforcement, previously, conv...
# 22247    [extracting, dimensional, structure, dimension...
# 21864    [inference, procedures, developed, regression,...
# 4476     [variation, algorithm, conjunction, experiment...
# 37135    [sufficient, condition, usability, condition, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8682 words.
# Out of those 4561 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9e2f7efa-874c-49f6-ad3a-d027e21310a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e2f7efa-874c-49f6-ad3a-d027e21310a6")) {                    Plotly.newPlot(                        "9e2f7efa-874c-49f6-ad3a-d027e21310a6",                        [{"x":["iteration","convergence","mathematical","application","dimensional","inequality","regression","penalized","derivatives","appropriate","particularly","important","coordinate","properties","bernstein","nonconvex","penalties","alternating","generalized","empirical","exemplify","estimation","linearized","thresholding","minimization","penalization","functions","procedures","lojasiewicz","algorithm","classification","completely","especially","practical","performance","applications","functional","investigated","capability","frequencies","different","displacement","strengths","evolutionary","literature","algorithms","environments","dimensions","experimental","structural","linearities","operators","introduces","investigate","deformation","complement","architectures","evaluation","corresponding","framework","convolutional","sensitivity","experiments","translation","including","lipschitz","wiatowski","establish","importance","considers","extraction","specifically","detection","continuous","reflected","handwritten","theoretical","inferring","implemented","differential","knowledge","industrial","unsupervised","paraphrase","automatically","paraphrases","outperforming","difficult","sentences","unannotated","phenomenon","represented","alignment","paraphrasing","comparable","determines","generation","representation","positions","combination","discovery","differentiable","computational","demonstrate","optimization","iteratively","optimized","optimizing","initialized","mimicking","increasing","competing","performing","enhancement","brightness","classical","quantitative","transformed","undesired","challenges","associated","qualitative","characteristic","relationship","unrelated","comprehensive","conditions","illuminations","candidates","implementations","intensities","apparently","connected","effective","visibility","observing","verification","generated","simulation","undecidable","deterministic","conjecture","consistency","traditional","equivalence","assumptions","stochastic","probabilistic","therefore","counterexamples","naturally","resulting","additional","consistent","intermediate","decidable","guarantee","partitions","hypothesis","condition","automated","partitioning","simultaneously","introducing","suboptimal","consuming","approaches","benchmark","incorporating","separately","benchmarks","components","efficient","maintaining","favorable","operation","efficiently","criterion","extractor","respectively","performed","convolution","nonetheless","challenging","individual","recurrent","generating","associate","description","structure","sensitive","descriptions","demonstrated","processes","parliament","political","coalitions","reliability","agreement","formation"],"y":[46,122,48,249,165,12,110,6,8,76,76,335,24,187,2,13,7,30,91,165,4,211,4,20,73,2,214,40,0,845,480,41,100,135,884,433,37,52,49,13,758,4,17,71,115,591,89,43,370,74,4,37,71,128,13,15,106,239,118,538,379,32,606,117,252,11,2,55,86,26,139,167,332,105,8,29,154,18,105,25,365,24,149,3,177,2,30,123,72,5,17,79,44,2,91,22,146,356,22,146,46,22,287,550,354,35,65,54,9,6,82,24,83,22,4,100,80,26,5,99,101,62,25,75,4,59,141,4,28,37,11,4,71,219,4,12,36,164,63,6,44,12,68,167,21,61,146,142,140,2,57,155,113,81,34,9,33,12,46,62,100,17,127,70,16,26,433,185,54,30,86,109,391,42,10,39,151,47,7,86,114,43,6,268,127,147,109,9,81,322,62,34,105,107,4,14,2,26,23,15],"type":"bar"},{"x":["iteration","convergence","mathematical","application","dimensional","ine ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4561,), (4561, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.805

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Query</span> <span style='background-color:rgba(0, 255, 0, 0.7627118644067796);'>Answering</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Contextualized</span> <span style=''>RDFOWL</span> <span style='background-color:rgba(0, 255, 0, 0.3721804511278195);'>Knowledge</span> <span style=''>with</span> <span style=''>Forall</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Existential</span> <span style=''>Bridge</span> <span style=''>Rules</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>Attaining</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Decidability</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Acyclicity</span> <span style=''>(full</span> <span style=''>version)</span> <br/><br/><span style=''>The</span> <span style=''>recent</span> <span style=''>outburst</span> <span style=''>of</span> <span style=''>context</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style='background-color:rgba(0, 255, 0, 0.3721804511278195);'>knowledge</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Semantic</span> <span style=''>Web</span> <span style=''>(SW)</span> <span style=''>has</span> <span style=''>led</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>realization</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>quads</span> <span style=''>in</span> <span style=''>the</span> <span style=''>SW</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>community</span> <span style=''>Quads</span> <span style=''>which</span> <span style=''>extend</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>RDF</span> <span style=''>triple</span> <span style=''>by</span> <span style=''>adding</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>of</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>an</span> <span style=''>RDF</span> <span style=''>triple</span> <span style=''>thus</span> <span style=''>informs</span> <span style=''>a</span> <span style=''>reasoner</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinguish</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3721804511278195);'>knowledge</span> <span style=''>in</span> <span style=''>various</span> <span style=''>contexts</span> <span style=''>Although</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>distinction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separates</span> <span style=''>the</span> <span style=''>triples</span> <span style=''>in</span> <span style=''>an</span> <span style=''>RDF</span> <span style=''>graph</span> <span style=''>into</span> <span style=''>various</span> <span style=''>contexts</span> <span style=''>and</span> <span style=''>allows</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.7622377622377623);'>reasoning</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decoupled</span> <span style=''>across</span> <span style=''>various</span> <span style=''>contexts</span> <span style=''>bridge</span> <span style=''>rules</span> <span style=''>need</span> <span style=''>to</span> <span style=''>be</span> <span style=''>provided</span> <span style=''>for</span> <span style=''>inter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>operating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3721804511278 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conformal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <br/><br/><span style=''>This</span> <span style=''>note</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>the</span> <span style=''>method</span> <span style=''>of</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conformal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>hybrid</span> <span style=''>of</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inductive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conformal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>and</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>and</span> <span style=''>studies</span> <span style=''>its</span> <span style=''>validity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style=''>Bandit</span> <span style=''>Sampling</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>work</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.36363636363636376);'>estimating</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>of</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>on</span> <span style=''>the</span> <span style=''>fly</span> <span style=''>by</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>datapoints</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uniformly</span> <span style=''>at</span> <span style=''>random</span> <span style=''>from</span> <span style=''>a</span> <span style=''>training</span> <span style=''>set</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5890410958904111);'>estimator</span> <span style=''>might</span> <span style=''>have</span> <span style=''>a</span> <span style=''>large</span> <span style=''>variance</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inadvertently</span> <span style=''>slows</span> <span style=''>down</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>One</span> <span style=''>way</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>this</span> <span style=''>variance</span> <span style=''>is</span> <span style=''>to</span> <span style=''>sample</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>datapoints</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>carefully</span> <span style=''>selected</span> <span style=''>non</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>non</span> <span style=''>uniform</span> <span style=''>sampling</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style='background-color:rgba(255, 0, 0, 0.35238095238095246);'>Theoretically</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.5862068965517242);'>asymptotically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximates</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>variance</span> <span style=''>within</span> <span style=''>a</span> <span style=''>factor</span> <span style=''>of</span> <span style=''>3</span> <span style='background-color:rgba(255, 0, 0, 0.3437500000000001);'>Empirically</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>using</span> <span style=''>this</span> <span style='background-color:rgba(2 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Critères</span> <span style=''>de</span> <span style=''>qualité</span> <span style=''>dun</span> <span style=''>classifieur</span> <span style=''>généraliste</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considers</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>choosing</span> <span style=''>a</span> <span style=''>good</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>For</span> <span style=''>each</span> <span style=''>problem</span> <span style=''>there</span> <span style=''>exist</span> <span style=''>an</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>but</span> <span style=''>none</span> <span style=''>are</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style=''>the</span> <span style=''>error</span> <span style=''>rate</span> <span style=''>in</span> <span style=''>all</span> <span style=''>cases</span> <span style=''>Because</span> <span style=''>there</span> <span style=''>exists</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>a</span> <span style=''>user</span> <span style=''>would</span> <span style=''>rather</span> <span style=''>prefer</span> <span style=''>an</span> <span style=''>all</span> <span style=''>purpose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>that</span> <span style=''>is</span> <span style=''>easy</span> <span style=''>to</span> <span style=''>adjust</span> <span style=''>in</span> <span style=''>the</span> <span style=''>hope</span> <span style=''>that</span> <span style=''>it</span> <span style=''>will</span> <span style=''>do</span> <span style=''>almost</span> <span style=''>as</span> <span style=''>good</span> <span style=''>as</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>a</span> <span style=''>list</span> <span style=''>of</span> <span style=''>criteria</span> <span style=''>that</span> <span style=''>a</span> <span style=''>good</span> <span style=''>generalist</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>should</span> <span style=''>satisfy</span> <span style=''>We</span> <span style=''>first</span> <span style=''>discuss</span> <span style=''>data</span> <span style=''>analytic</span> <span style=''>these</span> <span style=''>criteria</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>Six</span> <span style=''>among</span> <span style=''>the</span> <span style=''>most</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>are</span> <span style=''>selected</span> <span style=''>and</span> <span style=''>scored</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>according</span> <span style=''>to</span> <span style=''>these</span> <span style=''>criteria</span> <span style=''>Tables</span> <span style=''>allow</span> <span style=''>to</span> <span style=''>easily</span> <span style=''>appreciate</span> <span style=''>the</span> <span style=''>relative</span> <span style=''>values</span> <span style=''>of</span> <span style=''>each</span> <span style=''>In</span> <span style=''>the</span> <span style=''>end</span> <span style=''>random</span> <span style=''>forests</span> <span style=''>turn</span> <span style=''>out</span> <span style=''>to</span> <span style=''>be</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.24741163870046412)
# 	challenging (0.09568011424491253)
# 	knowledge (0.1303106033559443)
# 	representation (0.1270974651910032)
# 	segmentation (0.06640485540878258)
# 	architecture (0.08711174580506961)
# 	different (0.270617636558372)
# 	detection (0.1185290967511603)
# 	convolutional (0.135308818279186)
# 	recognition (0.13887897179578723)
#
# Some Statistics words are:
# 	variational (0.0945472736368184)
# 	algorithm (0.39619809904952474)
# 	variables (0.14357178589294647)
# 	statistical (0.16058029014507252)
# 	estimation (0.17408704352176088)
# 	theoretical (0.15607803901950976)
# 	distribution (0.1890945472736368)
# 	inference (0.2046023011505753)
# 	dimensional (0.18959479739869936)
# 	regression (0.18009004502251125)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="47e09091-4779-49a4-8980-f3804a2e8744" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47e09091-4779-49a4-8980-f3804a2e8744")) {                    Plotly.newPlot(                        "47e09091-4779-49a4-8980-f3804a2e8744",                        [{"x":["iteration","convergence","mathematical","application","dimensional","inequality","regression","penalized","derivatives","appropriate","particularly","important","coordinate","properties","bernstein","nonconvex","penalties","alternating","generalized","empirical","exemplify","estimation","linearized","thresholding","minimization","penalization","functions","procedures","lojasiewicz","algorithm","classification","completely","especially","practical","performance","applications","functional","investigated","capability","frequencies","different","displacement","strengths","evolutionary","literature","algorithms","environments","dimensions","experimental","structural","linearities","operators","introduces","investigate","deformation","complement","architectures","evaluation","corresponding","framework","convolutional","sensitivity","experiments","translation","including","lipschitz","wiatowski","establish","importance","considers","extraction","specifically","detection","continuous","reflected","handwritten","theoretical","inferring","implemented","differential","knowledge","industrial","unsupervised","paraphrase","automatically","paraphrases","outperforming","difficult","sentences","unannotated","phenomenon","represented","alignment","paraphrasing","comparable","determines","generation","representation","positions","combination","discovery","differentiable","computational","demonstrate","optimization","iteratively","optimized","optimizing","initialized","mimicking","increasing","competing","performing","enhancement","brightness","classical","quantitative","transformed","undesired","challenges","associated","qualitative","characteristic","relationship","unrelated","comprehensive","conditions","illuminations","candidates","implementations","intensities","apparently","connected","effective","visibility","observing","verification","generated","simulation","undecidable","deterministic","conjecture","consistency","traditional","equivalence","assumptions","stochastic","probabilistic","therefore","counterexamples","naturally","resulting","additional","consistent","intermediate","decidable","guarantee","partitions","hypothesis","condition","automated","partitioning","simultaneously","introducing","suboptimal","consuming","approaches","benchmark","incorporating","separately","benchmarks","components","efficient","maintaining","favorable","operation","efficiently","criterion","extractor","respectively","performed","convolution","nonetheless","challenging","individual","recurrent","generating","associate","description","structure","sensitive","descriptions","demonstrated","processes","parliament","political","coalitions","reliability","agreement","formation","interesting","methodologies","scenarios","exponential","krippendorffs","corresponds","perspective","analyzing","coalition","activities","technique","accumulation","amplitude","probabilities","processing","recognition","involving","magnitudes","likelihood","transform","connectionist","information","reasoning","probability","formulating","generalization","interpretation","amplitudes","disciplines","environmental","particular","protection","orchestration","landscapes","bioinformatics","mechanical","exploring","adaptability","richardson","highlighted","techniques","engineering","researchers","successfully","electromagnetic","scientific","systematic","impressive","essential","advancement","inception","generative","comparing","empiri ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	lojasiewicz
# 	isometric
# 	majorizer
# 	exemplifies
# 	misclassified
# 	pessimistic
# 	distributionally
# 	straightforwardly
# 	chemometrics
# 	sophistication
# 	concentrates
# 	factorizes
# 	sparsities
# 	uncollapsed
# 	emulating
# 	operationalize
# 	ingenious
# 	disconnected
# 	subroutines
# 	connectomics
# Some words which never appear in Statistics papers:
# 	displacement
# 	wiatowski
# 	paraphrase
# 	paraphrases
# 	unannotated
# 	paraphrasing
# 	brightness
# 	illuminations
# 	undecidable
# 	decidable
# 	parliament
# 	coalitions
# 	krippendorffs
# 	coalition
# 	connectionist
# 	amplitudes
# 	richardson
# 	electromagnetic
# 	contradicted
# 	comprehension

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.070215836173283e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
